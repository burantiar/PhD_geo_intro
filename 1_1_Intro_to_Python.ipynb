# %% [markdown]
# Intro to: <br>
# -	Python data types (lists, tuples, strings, integers, floats, dicts) <br>
# -	Programming basics (loops, if/else statements, operators) <br>
# -	Printing variables, getting help and installing libraries <br>
# -	Functions and inbuilt functions <br>
# -	Slicing lists <br>
# -	Working with directories of data
# -	Reading and writing textfiles
# -	Introduction to NumPy

# %% [markdown]
# Some tips
# - Use View - Toggle Line Numbers, for line numbers to appear (in Colab: Tools - Settings - Editor tab - Show line numbers)<br>
# - Use File - Download as - Python to get a Script (in Colab: File - Download - Download .py)<br>
# - Click save frequently <br>
# - Kernels can crash <br>
# - Be careful the order you run cells <br>
# - Jupyter Notebooks are good for presenting... development environments probably ok... commerical application - less so <br>

# %%
## don't forget to mount Google Drive when you use files stored in it
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Python basics

# %%
### data types (string, integer, float, boolean, list, dictionary, tuple)

myString = "hello"
myInt = 1
myFloat = 1.0
myBool = True
mylist = [1,2,3,4,5,6]
myDict = {'name': 'Andy', 'location': 'Cardiff'}
myTuple = (1,2,3,5,6)

print(myString)
print(myInt)
print(myFloat)
print(myBool)
print(mylist)
print(myDict)
print(myTuple)

# %% [markdown]
# Slicing is important when we start looking at raster data but for now lets consider it in lists and strings

# %%
## slicing
mylist = [1,2,3,4,5,6]
print(mylist [0]) # first item
print(mylist [0:3]) # first three items
print(mylist [:-4]) ## step back pos 4
print(mylist [-3:]) ## everything after pos 3

print()

## think about filenames as well!
filename1 = ".../A_shapefile.shp"
print(filename1)
print(filename1[:-4])
print(filename1[:-4] + "_buffer.shp")

# %%
## mutating lists
mylist = [1,2,3,4,5,6]
print(mylist)
print()

mylist.append(7) ## adds 7 to the end
mylist.insert(1,10) ## adds 10 to position 1
mylist.insert(1,10) ## adds 10 to position 1 - what happens to above? it becomes position 2
print(mylist)
print()

mylist.pop(4) ## remove the item found at position 4
print(mylist)
print()

mylist.remove(10) ## remove first instance of 10
print(mylist)

# %%
## create a new list based on another list

mynewlist = mylist[0:4] ## takes the first 4 values
print(mynewlist)
print(mylist)

mynewlist2 = myDict.copy()
print(type(mynewlist2))

# %%
## we cannot mutate tuples

print(myTuple)
myTuple.append(1)

# %%
## we can loop over both type
## names data and listdata don't matter really they could be anything

for data in myTuple:
    print(data)  
    
print()

for listdata in mylist:
    print(listdata)

# %%
## altering dictionaries
## adding
myDict = {'name': 'Andy', 'location': 'London'}
print(myDict)
print()

myDict['height'] = '170cm'

print(myDict)

## removing
del myDict['name']
print(myDict)

print()
print(myDict['location'])

print()
print(type(myDict['location'])) ## what type is this object

type(mylist)
print("Length = ", len(mylist))

# %%
## iterations, you can use for loop over a dictionary

for keys in myDict:
    print(keys)

print()   

for keys in myDict.items():
    print(keys) ## not keys

print()

# better way to itereate over dictionaries
for keys, values in myDict.items():
    print("Keys:", keys, "Values:", values)

# %%
## print the iterations or print the data
print(len(mylist))              ## how many items in the list
print(type(mylist))
print()

for i in range(0,len(mylist)):  ## not best practice
    print(i)

print()

## just the data
for data in mylist:
    print(data)

# %%
counter = 0
for i in range(0,len(mylist)): ## not! best practice
    print(mylist[i])
    #counter = counter + 1      # not optimal 
    counter +=1
    print(counter)

# %%
# but this isn't the best practice nor is it the fastest way
# use enumerate - it's built in

for counter, value in enumerate(mylist): ## much better!
    print(value)
    
print() 

# or

for counter, value in enumerate(mylist): 
    print(value)
    print(counter)
    print()
    
# sometimes you see _ as a variable this is in effect saying you don't need this - you may see it
for _, value in enumerate (mylist):
    print(value)

# %% [markdown]
# Getting help

# %%
import numpy as np
print(help(np.array))

# %% [markdown]
# Lib for plotting

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Conditional statements in a loop

# %%
for i in range(0,len(mylist)):
    print(mylist[i])
    if mylist[i] == 1:
        print("success we found a 1")
     
## or better
print()
for _, value in enumerate(mylist): ## much better!
    print(value)
    if value == 1:
        print("success we found a 1")
        # do something

# %%
for _, value in enumerate(mylist): ## much better!
    print(value)
    if value == 1 and i == 0:
        print("success we found a 1 and it was the first item")
    else:
        print("we didn't find a 1 here")

        
## https://www.tutorialspoint.com/python/python_if_else.htm

# %% [markdown]
# How long does the code take? (refactoring is something to think about)

# %%
# %%timeit

## create a list
mynewlist = list(range(100,201,5))    ## create a list of numbers from starting from 100 to 200(201), incrementing every five 
print(mynewlist)

# %%
## range with increment 1
range(10,20)

# %% [markdown]
# # Strings

# %%
## a little on strings

aString = "my,string,is,here"
print(aString)

# %% [markdown]
# String properties

# %%
## split strings
aString = "my,string,is,here"
mylist = aString.split(',')
print(mylist)
print(type(mylist))
print(type(mylist[0]))
print(mylist[0])

aString2 = "my string is here"
mylist2 = aString2.split(' ')
print(mylist2)

# %%
## upper case and lowercase
newstring = aString.upper()
print(newstring)
newstring_lower = newstring.lower()
print(newstring_lower)

# %% [markdown]
# Sometimes things don't quite work as you expect or like. Use print statements to help you

# %%
s = "-"
seq = ("a", "b", "c")     # This is sequence of strings.

print(type(seq))
print(s.join(seq))
print("")

## not going to work this way!
data = "hello, everyone."
data2 = "how are you?"
print(data.join(data2))

## better way to connect strings is to concatenate
print("")
data3 = data + " " + data2
print(data3)

# %% [markdown]
# # Functions

# %%
def my_first_function():
    print("hello world")

# %%
my_first_function()

# %%
def my_second_function(number):
    final_number = number + 100
    return final_number

# %%
new_number = my_second_function(10)
print(new_number)

# %%
def my_third_function():
    ## call second fuction and parse 10
    newnumber = my_second_function(10)      # you can call functions
    my_first_function()
    ## create a big number
    big_number = newnumber + 10000
    return(big_number)

# %%
large_number = my_third_function()
print (large_number)

# %% [markdown]
# # Operators

# %% [markdown]
# - "==" 	Equal
# > x == y
#
# - "!=" 	Not equal
# > x != y
#
# - ">"   Greater than
# > x > y
#
# - "<" 	Less than
# > x < y
#
# - ">=" 	Greater than or equal to
# > x >= y
#
# - "<=" 	Less than or equal to
# > x <= y
#
# - "%" modulo function (remainder)
#
# https://www.w3schools.com/python/python_operators.asp

# %% [markdown]
# # Errors

# %% [markdown]
# Whether we like it or not we will get errors. Errors are not the problem most of the time. You just need to understand what they are and what they mean.
# There is no fast way to learn this just practice.
#  Have a look at some examples below.

# %%
print("hello world)

# %%
print("hello world")

# %%
newNumber = 10 / 0

# %%
newNumber = 10 / 1

# %%
spam = 10
newspam = 10 * Spam

# %%
newspam = 10 + spam

# %%
number_of_shops_ = '2'
number_of_people_ = '10'
number_of_people_to_shop = number_of_people_ / number_of_shops_

# %%
number_of_shops = 2
number_of_people = 10
number_of_people_to_shop = number_of_people / number_of_shops
print(number_of_people_to_shop)
## or
number_of_people_to_shop = int(number_of_people_) / int (number_of_shops_)
print(number_of_people_to_shop)

# %%
for i in range(0,10)
    print(i)

# %%
for i in range(0,10):
    print(i)

# %%
### exception handling
### try statements and except

### the best way to think about error handling is to actually work with an error and we will look at this in conditional statements
data = "hello"
try:
    print(data / 2)
except:
    print("not a number")

# %% [markdown]
# # More complexity...
# Some additional bits that will help with scripting... generally as beginners you don't need to be too worried about this

# %%
## There are many additional parts of Python
## lets take a look at some

## zip function
## 2 lists
lsData1 = [1,2,3,4,5]
lsData2 = [10,11,12,14,15]

zippedData = zip(lsData1,lsData2)
print(zippedData)  ### an old python 2 hangover In Python3, 

## zip methods returns a zip object instead of a list. To access we need to iterate over it
for data_zip in zippedData:
    print(data_zip)

## or convert to list
zippedData = zip(lsData1,lsData2)
newzip = list(zippedData)
print(newzip)
print(type(newzip))

### why is this useful? coordinate pairs?

### can you zip other datatypes?

### what data type is it

## unziping data
print("")
zippedData = zip(lsData1,lsData2) 
print(type(zippedData))
lst1, lst2 = zip(*zippedData)
print(list(lst1))
print(list(lst2))

## zip is an iterator object that once we have accessed it we cannot again

# %%
## sorting lists

lsData = [1,5,2,8,6,5,4,1,2,5,7,8,9]
print("lsData")
print(lsData)
print("")

newls = lsData.copy() 
### do this instead of newls = lsData - this will mean any changes to lsData will also happen to newls

newls.sort(reverse=False)
print("newls")
print(newls)
print()
print("lsData")
print(lsData)
print("")

## reverse the sort
print("reverse")
lsData.sort(reverse=True)
print(lsData)

# %%
## just getting unique values from a list use set
lsData = [1,5,2,8,6,5,4,1,2,5,7,8,9]
unique_values = set(lsData)

print(unique_values)

print()

### make them a list
print(list(unique_values))

print()

### how many values in the list? use a dictionary!
counts = dict()
for data in lsData:
    #print(data)
    
    print(counts.get(data, 0)+1) ## you don't need to print unless you are unsure what is going on
    ## +1 because python counts 0,1,2,3 and we want 1,2,3,4 etc
    
    #print ("")
    counts[data] = counts.get(data, 0) + 1
    ## https://docs.quantifiedcode.com/python-anti-patterns/correctness/not_using_get_to_return_a_default_value_from_a_dictionary.html

print(counts) ## final counts

# %%
### small functions
## lambda

f = lambda x, y : x + y ### function to add two variables together

print(f)

# %%
print(f(1,2))
print()

## same as
def add(x,y):
    return x + y

print(add(1,2))

# %%
print(f("Andy", "Bob")) ## remember we did the join before?

# %%
### map function!!! 
## pass multiple values into a function or lambda
f = lambda x, y : x + y
print(f(1,2))

in1 = [1,2,3,4,5]
in2 = [2,4,5,6,7]

print(f(in1[0],in2[0]))
## same as above right!
print("")
# what has this created?
print(f(in1,in2))

## was that the expected result? (adding 2 lists)

# %%
## it added two lists together - which is what the function does ultimately

## use map instead if you want to sum on the item
f = lambda x, y : x + y

in1 = [1,2,3,4,5]
in2 = [2,4,5,6,7]

print(map(f,(in1,in2)))
## its a generator object - but not true at python 2.x (the above would have printed in Py2)
print(list(map(f,(in1),(in2))))

# %%
[x*2 for x in [66,53,0,94]] ### list comprehension mulitply by 2

# %%
[x + y for x,y in zip(in1,in2) ] ## same as before (the map function) - what is more readable?

## (1,2)
## (2,4)
## (3,5)
## (4,6)
## (5,7)

# %%
print([x + x for x in range(0,10)])

## unpack it to understand
print()

for x in range(0,10):
    print(x + x)
    # append to an empty list?

# %% [markdown]
# # Navigation
# This is a brief guide to navigating files and folders on your system

# %%
import os

### set the working directory
path_ = '/content/drive/MyDrive/GIS_tutorials/'      ## change the path to the folder!
    
## Get everything inside a directory
print("everything in the directory")
print(os.listdir(path_))
print()

## for loop to loop through the above
for file in os.listdir(path_):
    ### is the file ends with
    if file.endswith(".txt"):
        print(file)
        ### or join both the input directory to the file
        print(os.path.join(path_, file))

# %% [markdown]
# download data from https://qgis.org/downloads/data/qgis_sample_data.zip and place it into the '2_python_main_gis_functions' folder

# %%
## lets look at all shapefiles we have
mydir = path_ + "/2_python_main_gis_functions/qgis_sample_data"
for root, dir, files in os.walk(mydir):
    for file in files:
        #print(dir) ## no sub directory
        if file.endswith(".shp"):
             print(os.path.join(root, file))

# %%
## and are there files started with 'air'
for root, dir, files in os.walk(mydir):
    for file in files:
        #print(dir) ## no sub directory
        if file.startswith("air"):
             print(os.path.join(root, file))

# %%
### TIP
### .endswith will take multiple file extensions
### use a tuple

lsdata = []

for root, dir, files in os.walk(mydir):
    for file in files:
        if file.endswith((".shp",".prj")):
             print(os.path.join(root, file))

# %%
## CHALLENGE search your computer for all txt files and append each one to a list
## print the size of the longest path + filename (length) - they are string
## print the longest path + filename

## what about the shortest?

## how many characters in longest name, what is the longest name, what is the shortest name?

## try and write a function!

# %%
len(files) ## max, min and print length

# %%
path2 = str(os.environ.get('HOME'))     ## change path!

# %%
mydir = path2 
filelength  = 0
length = 0

for root, dir, files in os.walk(mydir):
    for file in files:
        if file.endswith((".txt")):
            lsdata.append(os.path.join(root, file))
             #print(os.path.join(root, file))

# %%
length = 0

def file_longest(mydir, nametype): 
    lsdata = []
    for root, dir, files in os.walk(mydir):
        for file in files:
            if file.endswith((".txt")):
                lsdata.append(os.path.join(root, file))
                 #print(os.path.join(root, file))


    for counter, value in enumerate(lsdata):
        filelength = len(value)
        if length < filelength:
            length = filelength
        else:
            length = length
        print(length)
        print(filename)

# %%
file_longest(mydir, ".txt")

# %% [markdown]
# # Text file manipulation

# %%
### This is where we start pulling together all this knowledge and doing something!

directory = '/content/drive/MyDrive/GIS_tutorials/2_python_main_gis_functions/'        ## change directory!
fileName = directory + "data_package_beg/Document1.txt"

### reading file line by line

f = open(fileName, 'r') 
for line in f: 
    print(line)
f.close()

# %%
### writing out a file

f = open(fileName, 'w')

f.write('5,3,3,2,Point5') 
f.write('6,4,5,1,Point6')

f.close()

# %%
### lets read the file again

f = open(fileName, 'r') 
for line in f: 
    print(line)
f.close()

# %% [markdown]
# Be careful the number of times you run the cell. You may need to delete the documentx.txt files and start again

# %%
### This is not the result we were expecting...
### It has overwritten the file and we also have everything on the same line
fileName2 = directory + "/Document2.txt"

f = open(fileName2, 'a') ### 'a' is append
f.write('5,3,3,2,Point5\n') ### \n is a special charater to add a new line
f.write('6,4,5,1,Point6\n')

f.close()

# %%
### lets read the file again - this time it works

f = open(fileName2, 'r') 
for line in f: 
    print(line)
f.close()

# %% [markdown]
# Creating a 'spatial' text file?

# %%
### creating a new textfile and writing out data generated into it

### 1. create the data
x = list(range(20,40))
y = list(range(30,50))
z = list(range(10,30))

## ID we will create dynamically
## Desc we will create dynamically

print(x)
print(y)
print(z)

# %% [markdown]
# Not really what we want... try a loop

# %%
### 2. loop through the data

for i in range(0,len(x)):
    print(x[i],y[i],z[i])

# %%
### 3. add the ID and description data
for i in range(0,len(x)):
    print(i+1,x[i],y[i],z[i],"Point" + str(i+1)) ### i+1 is increment to have ID's starting at 1, str is method to assign data to string

# %%
### 4. lets add in the comma's (convert everything to string)
### https://pyformat.info/ - string formatting

for i in range(0,len(x)):
    print(str(i+1)+","+str(x[i]) +","+str(y[i]) +"," +str(z[i])+","+"Point" + str(i+1))

# %%
### 5. looks good lets write this out to a text file, don't forget the new line \n!
fileName = directory + "data_package_beg/Document3.txt"

f = open(fileName, 'w')

for i in range(0,len(x)):
    ### we just need to swap out the print statement with the f.write()
    f.write(str(i+1)+","+str(x[i]) +","+str(y[i]) +"," +str(z[i])+","+"Point" + str(i+1)+'\n')

f.close() ## close file and you are done!

### congratulations you have written your first text file and generated all the data in python

# %%
## Full and final code - 8 lines of code!!

fileName =  directory + "data_package_beg/Document4.txt"

f = open(fileName, 'w')

x = list(range(20,40))
y = list(range(30,50))
z = list(range(10,30))
f.write("This is the new document structure!\n")
f.write("ID,X,Y,Z,POINT\n")
for i in range(0,len(x)):
    ### we just need to swap out the print statement with the f.write()
    f.write(str(i+1)+","+str(x[i]) +","+str(y[i]) +"," +str(z[i])+","+"Point" + str(i+1)+'\n')

f.close() ## close file and you are done!

# %%
# https://stackoverflow.com/questions/1369526/what-is-the-python-keyword-with-used-for
## save time with with :)
fileName =  directory + "data_package_beg/output.txt"

lsdata = []

for root, dir, files in os.walk(mydir):
    for file in files:
        if file.endswith((".shp",".prj")):
             lsdata.append(file)
                
                
with open(fileName, 'w') as f:
    for data in lsdata:
        f.write(str(data)+'\n')

# %% [markdown]
# It’s handy when you have two related operations which you’d like to execute as a pair, with a block of code in between. The classic example is opening a file, manipulating the file, then closing it:
#
#
# ```
# with open('output.txt', 'w') as f:
#     f.write('Hi there!')
# ```
#
#
# The above with statement will automatically close the file after the nested block of code. (Continue reading to see exactly how the close occurs.) The advantage of using a with statement is that it is guaranteed to close the file no matter how the nested block exits. If an exception occurs before the end of the block, it will close the file before the exception is caught by an outer exception handler. If the nested block were to contain a return statement, or a continue or break statement, the with statement would automatically close the file in those cases, too.

# %%
## Full and final code - 8 lines of code!!

fileName =  directory + "data_package_beg/Document5.txt"

with open(fileName, 'w') as f:

    x = list(range(20,40))
    y = list(range(30,50))
    z = list(range(10,30))
    #f.write("ID,X,Y,Z,POINT\n")
    for i in range(0,len(x)):
        ### we just need to swap out the print statement with the f.write()
        f.write(str(i+1)+","+str(x[i]) +","+str(y[i]) +"," +str(z[i])+","+"Point" + str(i+1)+'\n')

# %%
## challenge open elevap and read to a list all the x and y coordinates

## hint!! 
string = "Andrew;gives;clue"
print(string)
mylist = string.split(';')
print(mylist)

# %%
import csv

## Lets read the csv
fileName =  directory + "data_package_beg/elevp.csv"

# %%
with open(fileName, newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)

# %% [markdown]
# # NumPy
# Use Numpy arrays when refactoring... they are faster than lists

# %%
import numpy as np
x = np.arange(10)
print(x)

ls = list(range(10))
print(ls)

print(x[0:3])
print(ls[0:3])

for data in x:
    print(data)
    
print()
for data2 in ls:
    print(data2)

# %%
## Write a Python program to create a random vector of size 10 and sort it.

import numpy as np
x = np.random.random(10)
print("Original array:")
print(x)
print()
x.sort() ## we looked at this with lists
print("Sorted array:")
print(x)

# %%
## Write a Python program to check two random arrays are equal or not.

import numpy as np
x = np.random.randint(0,2,6)
print("First array:")
print(x)

y = np.random.randint(0,2,6)
print("Second array:")
print(y)

print("Test above two arrays are equal or not!")
array_equal = np.allclose(x, y)
print(array_equal)

## https://docs.scipy.org/doc/numpy/reference/generated/numpy.allclose.html

# %%
## Write a Python program to find the most frequent value in an array.

import numpy as np

x = np.random.randint(0, 10, 40)

print("Original array:")
print(x)

print(np.unique(x))
print(np.bincount(x)) ## number of 'bins'

print("Most frequent value in the above array:")
print(np.bincount(x).argmax()) ## argmax is maximum value

# %% [markdown]
# From the graphing challenge, we can read into a numpy array

# %%
directory = '/content/drive/MyDrive/GIS_tutorials/2_python_main_gis_functions/'      ## change directory!
fileName = directory + "data_package_beg/elevp.csv"

# %%
my_data = np.genfromtxt(fileName, dtype=int, delimiter=';', names=True)

print(my_data[0])
print(type(my_data))
print(my_data.shape)

print(len(my_data[0])) ## number of elements/items

### https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.savetxt.html 

np.savetxt(directory + "data_package_beg/" + 'elevp1.csv', my_data, delimiter=',', fmt='%i')

# %%
## normalising
Z = np.random.random((5,5))
print(Z)
print()
Zmax, Zmin = Z.max(), Z.min()
Z = (Z - Zmin)/(Zmax - Zmin)
print(Z)

# %%
## What am I doing here?

P = np.zeros((10,18))
N = np.full([10, 18], np.nan)

print(N.shape)
print()
print(N)


print()
P[4:6] = 1
print(P)
P[:,5:7] = 1
print()

print(P)

# %%
# %matplotlib inline
### Graphing is a very useful tool in python and matplotlib is the workhorse here
### Graphing is a very visual way of quickly seeing what is going on with your data

import matplotlib.pyplot as plt
import matplotlib as mpl
# Can be any colormap that you want after the cm
cmap = mpl.colors.ListedColormap(['blue', 'white'])
## Set the x and the y
plt.imshow(P, cmap=cmap)
plt.show()
