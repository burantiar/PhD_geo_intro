# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip install zarr
# Out:
# ...
#   Using cached zarr-3.1.5-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached zarr-3.1.5-py3-none-any.whl (284 kB)
# Using cached donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [zarr]━━━━━━━━━━━━━ 2/3 [zarr]
# ...

# %%
import seaborn as sns
import xarray as xr

sns.set_context("talk")

ds_sat = xr.open_zarr("../test/one/2021_nonhrv.zarr")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 6
#       2 import xarray as xr
#       4 sns.set_context("talk")
# ----> 6 ds_sat = xr.open_zarr("../test/one/2021_nonhrv.zarr")
#
# File ~/miniforge3/envs/tf/lib/python3.12/site-packages/xarray/backends/zarr.py:1586, in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, chunk_store, storage_options, decode_timedelta, use_cftime, zarr_version, zarr_format, use_zarr_fill_value_as_mask, chunked_array_type, from_array_kwargs, create_default_indexes, **kwargs)
#    1572     raise TypeError(
#    1573         "open_zarr() got unexpected keyword arguments " + ",".join(kwargs.keys())
#    1574     )
#    1576 backend_kwargs = {
#    1577     "synchronizer": synchronizer,
# ...

# %%
ds_sat.sel(time="2021-01-01 12:00", variable="VIS008").data.plot();

# %%
timestamp = "2020-06-01 12:00"

# Calculate the number of variables (columns)
num_vars = len(ds_sat.variable)


col_wrap = 3
num_rows = (num_vars + 3) // col_wrap  # Using 4 as col_wrap, adjust if different

# Calculate the figure size based on the image resolution of 614x372
fig_width = 6.14 * col_wrap
fig_height = 3.72 * num_rows

ds_sat.sel(time=timestamp).data.plot(
    col="variable",
    col_wrap=col_wrap,
    figsize=(fig_width, fig_height),
);
